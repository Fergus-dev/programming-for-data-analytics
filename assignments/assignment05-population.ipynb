# %%
import pandas as pd

# %%
url = "https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/FY006A/CSV/1.0/en"
df = pd.read_csv(url)

# %%
headers = df.columns.tolist()

# dropping general data from sex column (both sexes data) and age column (all ages data)
df = df[df['Sex'] != 'Both sexes']
df = df[df['Single Year of Age'] != 'All ages']
#print(df.head())
#print(df.tail())

# dropping unnecessary columns
columns_to_drop = ['STATISTIC', 'Statistic Label', 'TLIST(A1)', 'CensusYear', 'C02199V02655', 'C02076V03371', 'C03789V04537', 'Administrative Counties', 'UNIT']
df_revised = df.drop(columns=columns_to_drop)

# tidying up age values
df_revised['Single Year of Age'] = df_revised['Single Year of Age'].replace({'100 years and over': '100'})
df_revised['Single Year of Age'] = df_revised['Single Year of Age'].replace({'Under 1 year': '0'})

#print(df_revised.head())

# removing the word "year" from every row in the age column as well as any whitespace and then converting every value in column to an interger
# reference: https://www.sparkcodehub.com/pandas/data-cleaning/string-replace
df_revised['Single Year of Age'] = df_revised['Single Year of Age'].str.replace('years', '')
df_revised['Single Year of Age'] = df_revised['Single Year of Age'].str.replace('year', '')
df_revised['Single Year of Age'] = df_revised['Single Year of Age'].str.strip()
df_revised['Single Year of Age'] = df_revised['Single Year of Age'].astype(int)

#df_revised['Single Year of Age'] = df_revised['Single Year of Age'].astype(int)

#df_revised.to_csv('irish_population_by_age_and_sex.csv', index=False)

# %%
# calculating the weighted mean age and difference between the sexes by age
